# %% [markdown]
# Experiment 20
#
# Aim:Covid Data Analysis Project Analysis
#
# Name:Shravya Srivastava
#
# PRN:25070123106

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/covid_19_data.csv")
data.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
data = data.drop(['SNo','Last Update'],axis=1)
data.head()
# Out:
#   ObservationDate Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0      01/22/2020          Anhui  Mainland China        1.0     0.0        0.0
# 1      01/22/2020        Beijing  Mainland China       14.0     0.0        0.0
# 2      01/22/2020      Chongqing  Mainland China        6.0     0.0        0.0
# 3      01/22/2020         Fujian  Mainland China        1.0     0.0        0.0
# 4      01/22/2020          Gansu  Mainland China        0.0     0.0        0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ObservationDate  306429 non-null  object
#  1   Province/State   228326 non-null  object
#  2   Country/Region   306429 non-null  object
#  3   Confirmed        306429 non-null  float64
#  4   Deaths           306429 non-null  float64
#  5   Recovered        306429 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 14.0+ MB

# %%
data['ObservationDate'] = data['ObservationDate'].astype('datetime64[ns]')
data['Confirmed'] = data['Confirmed'].fillna(0).astype('int64')
data['Deaths'] = data['Deaths'].fillna(0).astype('int64')
data['Recovered'] = data['Recovered'].fillna(0).astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299657 entries, 0 to 299656
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ObservationDate  299657 non-null  datetime64[ns]
#  1   Province/State   222989 non-null  object
#  2   Country/Region   299657 non-null  object
#  3   Confirmed        299657 non-null  int64
#  4   Deaths           299657 non-null  int64
#  5   Recovered        299657 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 13.7+ MB

# %%
data.head()
# Out:
#   ObservationDate Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0      2020-01-22          Anhui  Mainland China          1       0          0
# 1      2020-01-22        Beijing  Mainland China         14       0          0
# 2      2020-01-22      Chongqing  Mainland China          6       0          0
# 3      2020-01-22         Fujian  Mainland China          1       0          0
# 4      2020-01-22          Gansu  Mainland China          0       0          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299657 entries, 0 to 299656
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ObservationDate  299657 non-null  datetime64[ns]
#  1   Province/State   222989 non-null  object
#  2   Country/Region   299657 non-null  object
#  3   Confirmed        299657 non-null  int64
#  4   Deaths           299657 non-null  int64
#  5   Recovered        299657 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 13.7+ MB

# %%
# Active Case
data['Active'] = data['Confirmed'] - data['Recovered'] - data['Deaths']
data.head(50)

data.iloc[50:100]
# Out:
#    ObservationDate  Province/State  Country/Region  Confirmed  Deaths  \
# 50      2020-01-23    Heilongjiang  Mainland China          2       0
# 51      2020-01-23           Henan  Mainland China          5       0
# 52      2020-01-23       Hong Kong       Hong Kong          2       0
# 53      2020-01-23           Hubei  Mainland China        444      17
# 54      2020-01-23           Hunan  Mainland China          9       0
# 55      2020-01-23  Inner Mongolia  Mainland China          0       0
# 56      2020-01-23         Jiangsu  Mainland China          5       0
# 57      2020-01-23         Jiangxi  Mainland China          7       0
# 58      2020-01-23           Jilin  Mainland China          1       0
# 59      2020-01-23        Liaoning  Mainland China          3       0
# 60      2020-01-23           Macau           Macau          2       0
# 61      2020-01-23         Ningxia  Mainland China          1       0
# 62      2020-01-23         Qinghai  Mainland China          0       0
# 63      2020-01-23         Shaanxi  Mainland China          3       0
# 64      2020-01-23        Shandong  Mainland China          6       0
# 65      2020-01-23        Shanghai  Mainland China         16       0
# 66      2020-01-23          Shanxi  Mainland China          1       0
# 67      2020-01-23         Sichuan  Mainland China          8       0
# 68      2020-01-23          Taiwan          Taiwan          1       0
# 69      2020-01-23         Tianjin  Mainland China          4       0
# 70      2020-01-23           Tibet  Mainland China          0       0
# 71      2020-01-23      Washington              US          1       0
# 72      2020-01-23        Xinjiang  Mainland China          2       0
# 73      2020-01-23          Yunnan  Mainland China          2       0
# 74      2020-01-23        Zhejiang  Mainland China         27       0
# 75      2020-01-23             NaN           Japan          1       0
# 76      2020-01-23             NaN        Thailand          4       0
# 77      2020-01-23             NaN     South Korea          1       0
# 78      2020-01-23             NaN       Singapore          1       0
# 79      2020-01-23             NaN     Philippines          0       0
# 80      2020-01-23             NaN        Malaysia          0       0
# 81      2020-01-23             NaN         Vietnam          2       0
# 82      2020-01-23             NaN       Australia          0       0
# 83      2020-01-23             NaN          Mexico          0       0
# 84      2020-01-23             NaN          Brazil          0       0
# 85      2020-01-23             NaN        Colombia          0       0
# 86      2020-01-23         Unknown           China          0       0
# 87      2020-01-23             NaN        Kiribati          0       0
# 88      2020-01-24           Hubei  Mainland China        549      24
# 89      2020-01-24       Guangdong  Mainland China         53       0
# 90      2020-01-24        Zhejiang  Mainland China         43       0
# 91      2020-01-24         Beijing  Mainland China         36       0
# 92      2020-01-24       Chongqing  Mainland China         27       0
# 93      2020-01-24           Hunan  Mainland China         24       0
# 94      2020-01-24         Guangxi  Mainland China         23       0
# 95      2020-01-24        Shanghai  Mainland China         20       0
# 96      2020-01-24         Jiangxi  Mainland China         18       0
# 97      2020-01-24         Sichuan  Mainland China         15       0
# 98      2020-01-24        Shandong  Mainland China         15       0
# 99      2020-01-24           Anhui  Mainland China         15       0
#
#     Recovered  Active
# 50          0       2
# 51          0       5
# 52          0       2
# 53         28     399
# 54          0       9
# 55          0       0
# 56          0       5
# 57          0       7
# 58          0       1
# 59          0       3
# 60          0       2
# 61          0       1
# 62          0       0
# 63          0       3
# 64          0       6
# 65          0      16
# 66          0       1
# 67          0       8
# 68          0       1
# 69          0       4
# 70          0       0
# 71          0       1
# 72          0       2
# 73          0       2
# 74          0      27
# 75          0       1
# 76          2       2
# 77          0       1
# 78          0       1
# 79          0       0
# 80          0       0
# 81          0       2
# 82          0       0
# 83          0       0
# 84          0       0
# 85          0       0
# 86          0       0
# 87          0       0
# 88         31     494
# 89          2      51
# 90          1      42
# 91          1      35
# 92          0      27
# 93          0      24
# 94          0      23
# 95          1      19
# 96          0      18
# 97          0      15
# 98          0      15
# 99          0      15

# %%
# last/current date
data['ObservationDate'].max()
# Out:
# Timestamp('2021-05-21 00:00:00')

# %%
# Fetch latest date data
latest_data = data[data['ObservationDate'] == data['ObservationDate'].max()]
latest_data.head()
# Out:
#        ObservationDate Province/State Country/Region  Confirmed  Deaths  \
# 299544      2021-05-21            NaN    Afghanistan      65080    2782
# 299545      2021-05-21            NaN        Albania     132153    2441
# 299546      2021-05-21            NaN        Algeria     126434    3405
# 299547      2021-05-21            NaN        Andorra      13569     127
# 299548      2021-05-21            NaN         Angola      31909     709
#
#         Recovered  Active
# 299544      55790    6508
# 299545     128425    1287
# 299546      88066   34963
# 299547      13234     208
# 299548      26513    4687

# %%
latest_data.shape
# Out:
# (113, 7)

# %%
latest_data['Country/Region'].value_counts()
# Out:
# Country/Region
# Afghanistan    1
# Albania        1
# Algeria        1
# Andorra        1
# Angola         1
#               ..
# Morocco        1
# Mozambique     1
# Namibia        1
# Nepal          1
# New Zealand    1
# Name: count, Length: 113, dtype: int64

# %%
latest_data['Country/Region'].nunique()
# Out:
# 113

# %%
latest_data['Country/Region'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Burma', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Central African Republic', 'Chad', 'Comoros',
#        'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czech Republic', 'Denmark', 'Diamond Princess',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Ghana', 'Greece', 'Grenada', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Holy See',
#        'Honduras', 'Hungary', 'Iceland', 'Indonesia', 'Iran', 'Iraq',
#        'Ireland', 'Israel', 'Ivory Coast', 'Jamaica', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'MS Zaandam',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Micronesia',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Namibia', 'Nepal', 'New Zealand'], dtype=object)

# %%
# Count of cases for each country
countries = latest_data.groupby("Country/Region")[["Confirmed","Deaths","Recovered","Active"]].sum()

countries = countries.reset_index()

# %%
countries
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active
# 0      Afghanistan      65080    2782      55790    6508
# 1          Albania     132153    2441     128425    1287
# 2          Algeria     126434    3405      88066   34963
# 3          Andorra      13569     127      13234     208
# 4           Angola      31909     709      26513    4687
# ..             ...        ...     ...        ...     ...
# 108        Morocco     516449    9115     504757    2577
# 109     Mozambique      70551     831      68845     875
# 110        Namibia      52433     759      48951    2723
# 111          Nepal     497052    6024     374836  116192
# 112    New Zealand          0       0          0       0
#
# [113 rows x 5 columns]

# %%
countries[countries['Country/Region']=="Mainland China"]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active]
# Index: []

# %%
countries[countries['Country/Region']=="US"]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active]
# Index: []

# %%
countries[countries['Country/Region']=="India"]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active]
# Index: []

# %%
countries['Country/Region']=="Mainland China"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# Name: Country/Region, Length: 113, dtype: bool

# %%
# Plot on World Map
import plotly.express as px
world_map = px.choropleth(countries,locations="Country/Region",locationmode="country names",
                          color="Confirmed",color_continuous_scale="reds",range_color=[0,10000000])
world_map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d617ebb-8991-45fa-a2af-61aa792748a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d617ebb-8991-45fa-a2af-61aa792748a1")) {                    Plotly.newPlot(                        "5d617ebb-8991-45fa-a2af-61aa792748a1",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country\u002fRegion=%{location}\u003cbr\u003eConfirmed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Afghanistan","Albania","Algeria","Andorra","Angola","Antigua and Barbuda","Argentina","Armenia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belize","Benin","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brunei","Bulgaria","Burkina Faso","Burma","Burundi","Cabo Verde","Cambodia","Cameroon","Central African Republic","Chad","Comoros","Congo (Brazzaville)","Congo (Kinshasa)","Costa Rica","Croatia","Cuba","Cyprus","Czech Republic","Denmark","Diamond Princess","Djibouti","Dominica","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Fiji","Finland","France","Gabon","Gambia","Georgia","Ghana","Greece","Grenada","Guatemala","Guinea","Guinea-Bissau","Guyana","Haiti","Holy See","Honduras","Hungary","Iceland","Indonesia","Iran","Iraq","Ireland","Israel","Ivory Coast","Jamaica","Jordan","Kazakhstan","Kenya","Kiribati","Kosovo","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Libya","Liechtenstein","Lithuania","Luxembourg","MS Zaandam","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Marshall Islands","Mauritania","Mauritius","Micronesia","Moldova","Monaco","Mongolia","Montenegro","Morocco","Mozambique","Namibia","Nepal","New Zealand"],"name":"","z":[65080,132153,126434,13569,31909,1255,3482512,221699,640293,331883,11396,212151,786698,3985,383302,12764,8025,1374,343065,203150,51620,235,416417,13410,143211,4451,29033,24157,77733,7010,4919,3868,11476,30825,299219,353217,130543,71745,1656874,271908,712,11490,184,281630,416621,251539,72220,8436,3921,128309,18546,268520,195,91157,5526555,24107,5968,335769,93521,387426,161,246156,22963,3749,15743,13624,27,231560,801025,6555,1764644,2815882,1160494,254870,839290,46874,47776,726432,425397,167535,2,106770,297206,101878,1763,130271,537887,10806,2142,182899,2997,269363,69545,9,40692,34261,498795,52405,14236,30497,4,19049,1292,1,254499,2500,51931,99153,516449,70551,52433,497052,0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1 ...

# %%
world_map = px.choropleth(countries,locations="Country/Region",locationmode="country names",
                          color="Recovered",color_continuous_scale="greens",range_color=[0,10000000])
world_map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c1f56fe0-b293-41d6-aa0f-336c3125725f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1f56fe0-b293-41d6-aa0f-336c3125725f")) {                    Plotly.newPlot(                        "c1f56fe0-b293-41d6-aa0f-336c3125725f",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country\u002fRegion=%{location}\u003cbr\u003eRecovered=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Afghanistan","Albania","Algeria","Andorra","Angola","Antigua and Barbuda","Argentina","Armenia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belize","Benin","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brunei","Bulgaria","Burkina Faso","Burma","Burundi","Cabo Verde","Cambodia","Cameroon","Central African Republic","Chad","Comoros","Congo (Brazzaville)","Congo (Kinshasa)","Costa Rica","Croatia","Cuba","Cyprus","Czech Republic","Denmark","Diamond Princess","Djibouti","Dominica","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Fiji","Finland","France","Gabon","Gambia","Georgia","Ghana","Greece","Grenada","Guatemala","Guinea","Guinea-Bissau","Guyana","Haiti","Holy See","Honduras","Hungary","Iceland","Indonesia","Iran","Iraq","Ireland","Israel","Ivory Coast","Jamaica","Jordan","Kazakhstan","Kenya","Kiribati","Kosovo","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Libya","Liechtenstein","Lithuania","Luxembourg","MS Zaandam","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Marshall Islands","Mauritania","Mauritius","Micronesia","Moldova","Monaco","Mongolia","Montenegro","Morocco","Mozambique","Namibia","Nepal","New Zealand"],"name":"","z":[55790,128425,88066,13234,26513,1188,3060145,210464,620837,319271,10221,191522,729039,3922,373391,12358,7893,1186,277711,172005,48449,222,372968,13225,132169,773,26456,16524,35261,5112,4719,3710,8208,27603,228589,340728,122764,39061,1603764,255624,699,11313,176,235608,354499,185243,67510,7801,3711,120140,17824,225480,129,46000,324444,20976,5727,316389,91458,93764,160,226014,20614,3478,13453,12463,27,83506,661564,6476,1626142,2304824,1072026,23364,832279,46282,23742,710445,385566,114394,0,100883,282913,95114,800,120348,507424,6427,2022,169733,2910,244635,67162,7,38950,32262,444540,31197,9418,29984,4,18231,1151,1,246080,2458,45853,96448,504757,68845,48951,374836,0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921 ...

# %%
# count of cases datewise
total_cases = data.groupby("ObservationDate")[["Confirmed","Deaths","Recovered","Active"]].sum().reset_index()
total_cases
# Out:
#     ObservationDate  Confirmed   Deaths  Recovered    Active
# 0        2020-01-22        557       17         30       510
# 1        2020-01-23       1097       34         60      1003
# 2        2020-01-24        941       26         39       876
# 3        2020-01-25       1437       42         42      1353
# 4        2020-01-26       2118       56         56      2006
# ..              ...        ...      ...        ...       ...
# 481      2021-05-17  163609626  3390170   99808931  60410525
# 482      2021-05-18  164231811  3404419  100552044  60275348
# 483      2021-05-19  164902903  3417763  101250071  60235069
# 484      2021-05-20  165182316  3430539  101886760  59865017
# 485      2021-05-21   32081489   655365   23479164   7946960
#
# [486 rows x 5 columns]

# %%
# Top countries having maximum confirmed and recovered cases
top = latest_data.groupby("Country/Region")[['Confirmed','Recovered']].sum().reset_index()
top = top.sort_values(['Confirmed'],ascending=False)
top.head()
# Out:
#     Country/Region  Confirmed  Recovered
# 54          France    5526555     324444
# 6        Argentina    3482512    3060145
# 71            Iran    2815882    2304824
# 70       Indonesia    1764644    1626142
# 38  Czech Republic    1656874    1603764

# %%
top_20 = top.head(20)
top_20
# Out:
#      Country/Region  Confirmed  Recovered
# 54           France    5526555     324444
# 6         Argentina    3482512    3060145
# 71             Iran    2815882    2304824
# 70        Indonesia    1764644    1626142
# 38   Czech Republic    1656874    1603764
# 72             Iraq    1160494    1072026
# 74           Israel     839290     832279
# 68          Hungary     801025     661564
# 12       Bangladesh     786698     729039
# 77           Jordan     726432     710445
# 8           Austria     640293     620837
# 86          Lebanon     537887     507424
# 108         Morocco     516449     504757
# 96         Malaysia     498795     444540
# 111           Nepal     497052     374836
# 78       Kazakhstan     425397     385566
# 44          Ecuador     416621     354499
# 22         Bulgaria     416417     372968
# 59           Greece     387426      93764
# 14          Belarus     383302     373391

# %%
# India
india = data[data['Country/Region']=="India"]
india
# Out:
#        ObservationDate Province/State Country/Region  Confirmed  Deaths  \
# 446         2020-01-30            NaN          India          1       0
# 509         2020-01-31            NaN          India          1       0
# 567         2020-02-01            NaN          India          1       0
# 629         2020-02-02            NaN          India          2       0
# 696         2020-02-03            NaN          India          3       0
# ...                ...            ...            ...        ...     ...
# 299466      2021-05-20        Tripura          India      44359     455
# 299481      2021-05-20        Unknown          India          0       0
# 299492      2021-05-20  Uttar Pradesh          India    1651530   18588
# 299493      2021-05-20    Uttarakhand          India     303940    5484
# 299521      2021-05-20    West Bengal          India    1209958   13895
#
#         Recovered  Active
# 446             0       1
# 509             0       1
# 567             0       1
# 629             0       2
# 696             0       3
# ...           ...     ...
# 299466      37097    6807
# 299481          0       0
# 299492    1516508  116434
# 299493     229813   68643
# 299521    1064553  131510
#
# [12849 rows x 7 columns]

# %%
# Find total number of states
india['Province/State'].nunique()
# Out:
# 38

# %%
# Find names of states
india['Province/State'].unique()
# Out:
# array([nan, 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadar Nagar Haveli', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Unknown', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Lakshadweep'], dtype=object)

# %%
india['Province/State'] = india['Province/State'].fillna("Unknown")
# Out:
# /tmp/ipykernel_5621/1748090106.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
india['Province/State'].unique()
# Out:
# array(['Unknown', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadar Nagar Haveli', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Lakshadweep'], dtype=object)

# %%
india['Province/State'].nunique()
# Out:
# 38

# %%
#india_latest_data
india_latest_data = india[india['ObservationDate'] ==india['ObservationDate'].max()]
india_latest_data
# Out:
#        ObservationDate                            Province/State  \
# 298970      2021-05-20               Andaman and Nicobar Islands
# 298971      2021-05-20                            Andhra Pradesh
# 298988      2021-05-20                         Arunachal Pradesh
# 298989      2021-05-20                                     Assam
# 299011      2021-05-20                                     Bihar
# 299045      2021-05-20                                Chandigarh
# 299052      2021-05-20                              Chhattisgarh
# 299071      2021-05-20  Dadra and Nagar Haveli and Daman and Diu
# 299075      2021-05-20                                     Delhi
# 299111      2021-05-20                                       Goa
# 299127      2021-05-20                                   Gujarat
# 299133      2021-05-20                                   Haryana
# 299140      2021-05-20                          Himachal Pradesh
# 299166      2021-05-20                         Jammu and Kashmir
# 299169      2021-05-20                                 Jharkhand
# 299187      2021-05-20                                 Karnataka
# 299190      2021-05-20                                    Kerala
# 299215      2021-05-20                                    Ladakh
# 299216      2021-05-20                               Lakshadweep
# 299236      2021-05-20                            Madhya Pradesh
# 299242      2021-05-20                               Maharashtra
# 299244      2021-05-20                                   Manipur
# 299257      2021-05-20                                 Meghalaya
# 299271      2021-05-20                                   Mizoram
# 299283      2021-05-20                                  Nagaland
# 299327      2021-05-20                                    Odisha
# 299361      2021-05-20                                Puducherry
# 299365      2021-05-20                                    Punjab
# 299375      2021-05-20                                 Rajasthan
# 299424      2021-05-20                                    Sikkim
# 299445      2021-05-20                                Tamil Nadu
# 299449      2021-05-20                                 Telangana
# 299466      2021-05-20                                   Tripura
# 299481      2021-05-20                                   Unknown
# 299492      2021-05-20                             Uttar Pradesh
# 299493      2021-05-20                               Uttarakhand
# 299521      2021-05-20                               West Bengal
#
#        Country/Region  Confirmed  Deaths  Recovered  Active
# 298970          India       6758      96       6401     261
# 298971          India    1521142    9800    1302208  209134
# 298988          India      23159      89      20339    2731
# 298989          India     353574    2507     297902   53165
# 299011          India     676045    4241     617397   54407
# 299045          India      57331     666      50592    6073
# 299052          India     936423   12295     842662   81466
# 299071          India       9850       4       9174     672
# 299075          India    1409950   22579    1347157   40214
# 299111          India     141567    2272     118487   20808
# 299127          India     776220    9404     677798   89018
# 299133          India     722964    7205     653407   62352
# 299140          India     172722    2595     136679   33448
# 299166          India     260057    3422     206081   50554
# 299169          India     324884    4714     293659   26511
# 299187          India    2335524   23854    1776695  534975
# 299190          India    2263959    6852    1938887  318220
# 299215          India      17025     172      15264    1589
# 299216          India       5756      20       4072    1664
# 299236          India     752735    7315     672695   72725
# 299242          India    5497448   85355    5026308  385785
# 299244          India      41909     646      34359    6904
# 299257          India      26927     389      20061    6477
# 299271          India       9740      30       7407    2303
# 299283          India      19284     245      14520    4519
# 299327          India     655899    2403     556501   96995
# 299361          India      91465    1269      71919   18277
# 299365          India     523423   12716     443666   67041
# 299375          India     897193    7346     745873  143974
# 299424          India      12204     217       8865    3122
# 299445          India    1734804   19131    1452283  263390
# 299449          India     544263    3060     495446   45757
# 299466          India      44359     455      37097    6807
# 299481          India          0       0          0       0
# 299492          India    1651530   18588    1516508  116434
# 299493          India     303940    5484     229813   68643
# 299521          India    1209958   13895    1064553  131510

# %%
top_state = india_latest_data.groupby("Province/State")[['Confirmed','Recovered']].sum().reset_index()
top_state = top_state.sort_values(['Confirmed'],ascending=False)
top_state.head(20)
# Out:
#     Province/State  Confirmed  Recovered
# 20     Maharashtra    5497448    5026308
# 15       Karnataka    2335524    1776695
# 16          Kerala    2263959    1938887
# 30      Tamil Nadu    1734804    1452283
# 34   Uttar Pradesh    1651530    1516508
# 1   Andhra Pradesh    1521142    1302208
# 8            Delhi    1409950    1347157
# 36     West Bengal    1209958    1064553
# 6     Chhattisgarh     936423     842662
# 28       Rajasthan     897193     745873
# 10         Gujarat     776220     677798
# 19  Madhya Pradesh     752735     672695
# 11         Haryana     722964     653407
# 4            Bihar     676045     617397
# 25          Odisha     655899     556501
# 31       Telangana     544263     495446
# 27          Punjab     523423     443666
# 3            Assam     353574     297902
# 14       Jharkhand     324884     293659
# 35     Uttarakhand     303940     229813

# %%
top_state['Confirmed'].max()
# Out:
# 5497448

# %%
top_state[top_state['Confirmed']==top_state['Confirmed'].max()]['Province/State'].values[0]
# Out:
# 'Maharashtra'
